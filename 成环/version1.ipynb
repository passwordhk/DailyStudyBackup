# %%
import re
f = open('1660k.data','r')
all_li = f.readlines()
new = all_li[16:]
content = []
for i in new:
    content.append(i.strip().split())
for i in content:
    if i[1] == '1':
        i[0] = f'C{i[0]}'
    elif i[1] == '2':
        i[0] = f'H{i[0]}'
    elif i[1] == '3':
        i[0] = f'O{i[0]}'
C = []
H = []
O = []
for i in content:
    if i[0].startswith('C'):
        C.append(i[0])
    elif i[0].startswith('H'):
        H.append(i[0])
    elif i[0].startswith('O'):
        O.append(i[0])
# 获取原子固定编号
O_index = [i[1:] for i in O]
C_index = [i[1:] for i in C]
H_index = [i[1:] for i in H]

# %%
f=open('bonds.reax')
a=f.readlines()[7:]
C_O = []
for i in a:
    for j in O_index:
        if j in i:
            C_O.append(i.strip().split())
# print(len(C_O))
def istype_convert(s):
    a = None
    if s in O_index:
        a = f'O{s}'
    elif s in C_index:
        a = f'C{s}'
    elif s in H_index:
        a = f'H{s}'
    return a


def convert_index(li):
    for i,j in enumerate(li):
        if j=='0':
            b = [0] + [k for k in range(3,i)]
            return b
    
    
# print(len(C_O))
for i in range(len(C_O)):
    for j in convert_index(C_O[i]):
        C_O[i][j] = istype_convert(C_O[i][j])

def get_count_rear(li):
    for index,value in enumerate(li):
        if value == '0':
            return index-3
        
def cal_mass(formula):
  MM_of_Elements = {'H': 1.00794, 'He': 4.002602, 'Li': 6.941, 'Be': 9.012182, 'B': 10.811, 'C': 12.0107, 'N': 14.0067,
                'O': 15.9994, 'F': 18.9984032, 'Ne': 20.1797, 'Na': 22.98976928, 'Mg': 24.305, 'Al': 26.9815386,
                'Si': 28.0855, 'P': 30.973762, 'S': 32.065, 'Cl': 35.453, 'Ar': 39.948, 'K': 39.0983, 'Ca': 40.078,
                'Sc': 44.955912, 'Ti': 47.867, 'V': 50.9415, 'Cr': 51.9961, 'Mn': 54.938045,
                'Fe': 55.845, 'Co': 58.933195, 'Ni': 58.6934, 'Cu': 63.546, 'Zn': 65.409, 'Ga': 69.723, 'Ge': 72.64,
                'As': 74.9216, 'Se': 78.96, 'Br': 79.904, 'Kr': 83.798, 'Rb': 85.4678, 'Sr': 87.62, 'Y': 88.90585,
                'Zr': 91.224, 'Nb': 92.90638, 'Mo': 95.94, 'Tc': 98.9063, 'Ru': 101.07, 'Rh': 102.9055, 'Pd': 106.42,
                'Ag': 107.8682, 'Cd': 112.411, 'In': 114.818, 'Sn': 118.71, 'Sb': 121.760, 'Te': 127.6,
                'I': 126.90447, 'Xe': 131.293, 'Cs': 132.9054519, 'Ba': 137.327, 'La': 138.90547, 'Ce': 140.116,
                'Pr': 140.90465, 'Nd': 144.242, 'Pm': 146.9151, 'Sm': 150.36, 'Eu': 151.964, 'Gd': 157.25,
                'Tb': 158.92535, 'Dy': 162.5, 'Ho': 164.93032, 'Er': 167.259, 'Tm': 168.93421, 'Yb': 173.04,
                'Lu': 174.967, 'Hf': 178.49, 'Ta': 180.9479, 'W': 183.84, 'Re': 186.207, 'Os': 190.23, 'Ir': 192.217,
                'Pt': 195.084, 'Au': 196.966569, 'Hg': 200.59, 'Tl': 204.3833, 'Pb': 207.2, 'Bi': 208.9804,
                'Po': 208.9824, 'At': 209.9871, 'Rn': 222.0176, 'Fr': 223.0197, 'Ra': 226.0254, 'Ac': 227.0278,
                'Th': 232.03806, 'Pa': 231.03588, 'U': 238.02891, 'Np': 237.0482, 'Pu': 244.0642, 'Am': 243.0614,
                'Cm': 247.0703, 'Bk': 247.0703, 'Cf': 251.0796, 'Es': 252.0829, 'Fm': 257.0951, 'Md': 258.0951,
                'No': 259.1009, 'Lr': 262, 'Rf': 267, 'Db': 268, 'Sg': 271, 'Bh': 270, 'Hs': 269, 'Mt': 278,
                'Ds': 281, 'Rg': 281, 'Cn': 285, 'Nh': 284, 'Fl': 289, 'Mc': 289, 'Lv': 292, 'Ts': 294, 'Og': 294,
                'ZERO': 0}

  Compound = formula
  IsPolyatomic, End, Multiply = False, False, False
  PolyatomicMass, MM, Multiplier = 0, 0, 1
  Element = 'ZERO'

  for i in range(0, len(Compound) + 1):
    E = Compound[i:i + 1]
    if IsPolyatomic:
        if End:
            IsPolyatomic = False
            MM += int(E) * PolyatomicMass
        elif E.isdigit():
            if Multiply: Multiplier = int(str(Multiplier) + E)
            else: Multiplier = int(E)
            Multiply = True
        elif E.islower(): Element += E
        elif E.isupper():
            PolyatomicMass += Multiplier * MM_of_Elements[Element]
            Element, Multiplier, Multiply = E, 1, False
        elif E == ')':
            PolyatomicMass += Multiplier * MM_of_Elements[Element]
            Element, Multiplier = 'ZERO', 1
            End, Multiply = True, False
    elif E == '(':
        MM += Multiplier * MM_of_Elements[Element]
        Element, Multiplier = 'ZERO', 1
        IsPolyatomic, Multiply = True, False
    elif E.isdigit():
        if Multiply:
            Multiplier = int(str(Multiplier) + E)
        else: Multiplier = int(E)
        Multiply = True
    elif E.islower(): Element += E
    elif E.isupper():
        MM += Multiplier * MM_of_Elements[Element]
        Element, Multiplier, Multiply = E, 1, False
    elif i == len(Compound):
        MM += Multiplier * MM_of_Elements[Element]
        Element, Multiplier, Multiply = E, 1, False
  return MM

sc = []        
for i in C_O:
#     print(get_count_rear(i))
    if get_count_rear(i) == 1:
        sc.append(i)     
goal = [i for i in C_O if i not in sc]
sc1 = []  

# print(goal)
for i in goal:
    if get_count_rear(i) == 2:
        str_temp = i[0][0]+i[3][0]+i[4][0]
        if cal_mass(str_temp)<29:
            sc1.append(i)
last = [i for i in goal if i not in sc1]    


# for i in last:
#     print(i)

    
    
# single = 0
# double = 0
# for i in last:
#     if i[0][0] =='O':
#         if get_count_rear(i) == 2:
#             for index,j in enumerate(i):
#                 if j.startswith('C'):
#                     if float(i[index+3])<1:
#                         print('C-O 单键')
#                         single += 1
#                     elif 1<float(i[index+3])<2:
#                         double += 1
#                         print('C-O 双键')
#                     elif float(i[index+4])>2:
#                         print('C-O 三键')
                        
#         elif get_count_rear(i) == 3:
#             for index,j in enumerate(i):
#                 if j.startswith('C'):
#                     if float(i[index+4])<1:
#                         print('C-O 单键')
#                         single += 1
#                     elif 1<float(i[index+4])<2:
#                         print('C-O 双键')
#                         double += 1
#                     elif float(i[index+4])>2:
#                         print('C-O 三键')
        
#         elif get_count_rear(i) == 4:
#             for index,j in enumerate(i):
#                 if j.startswith('C'):
#                     if float(i[index+5])<1:
#                         print('C-O 单键')
#                         single += 1
#                     elif 1<float(i[index+5])<2:
#                         print('C-O 双键')
#                         double += 1
#                     elif float(i[index+5])>2:
#                         print('C-O 三键')
                
#     elif i[0][0] =='C':
#         if get_count_rear(i) == 2:
#             for index,j in enumerate(i):
#                 if j.startswith('O'):
#                     if 0<float(i[index+3])<1:
#                         print('C-O 单键')
#                         single += 1
#                     elif 1<float(i[index+3])<2:
#                         print('C-O 双键')
#                         double += 1
#                     elif float(i[index+3])>2:
#                         print('C-O 三键')
                        
#         elif get_count_rear(i) == 3:
#             for index,j in enumerate(i):
#                 if j.startswith('O'):
#                     if 0<float(i[index+4])<1:
#                         print('C-O 单键')
#                         single += 1
#                     elif 1<float(i[index+4])<2:
#                         print('C-O 双键')
#                         double += 1
#                     elif float(i[index+4])>2:
#                         print('C-O 三键')
                        
#         elif get_count_rear(i) == 4:
#             for index,j in enumerate(i):
#                 if j.startswith('O'):
#                     if float(i[index+5])<1:
#                         print('C-O 单键')
#                         single += 1
#                     elif 1<float(i[index+5])<2:
#                         print('C-O 双键')
#                         double += 1
#                     elif float(i[index+5])>2:
#                         print('C-O 三键')
                        
# print(f'单键{single} 双键{double}')    
for i in last:
    print(i)
print(len(last))
def eliminate(li):
    for i in li:
        pass
# Out:
# ['C967', '1', '4', 'C964', 'H979', 'O1354', 'C968', '0', '1.049', '0.926', '0.999', '0.859', '3.853', '0.000', '0.108']
# ['O1354', '3', '2', 'H1353', 'C967', '0', '0.837', '0.999', '1.848', '2.000', '-0.208']
# ['C1418', '1', '2', 'O1358', 'C1417', '0', '0.867', '1.685', '2.554', '0.155', '0.167']
# ['O1358', '3', '2', 'C1418', 'H1357', '0', '0.867', '0.963', '1.831', '2.000', '-0.264']
# ['O1332', '3', '2', 'H1331', 'C1205', '0', '0.906', '0.938', '1.844', '2.000', '-0.226']
# ['C1205', '1', '2', 'O1332', 'C1206', '0', '0.938', '1.328', '2.266', '0.650', '0.131']
# ['C1433', '1', '2', 'O1360', 'C1434', '0', '1.821', '1.468', '3.290', '0.000', '0.207']
# ['C1495', '1', '3', 'C1494', 'C1491', 'O1350', '0', '1.451', '0.972', '1.123', '3.731', '0.000', '0.184']
# ['O1350', '3', '2', 'C1495', 'H1349', '0', '1.123', '0.902', '2.045', '1.988', '-0.240']
# ['O1346', '3', '2', 'H1530', 'C1525', '0', '0.902', '0.966', '1.882', '2.000', '-0.252']
# ['C1525', '1', '3', 'C1521', 'O1346', 'O1334', '0', '1.418', '0.966', '1.161', '3.608', '0.000', '0.288']
# ['C1525', '1', '3', 'C1521', 'O1346', 'O1334', '0', '1.418', '0.966', '1.161', '3.608', '0.000', '0.288']
# ['O1334', '3', '2', 'C1525', 'H1333', '0', '1.161', '0.845', '2.014', '1.999', '-0.235']
# ['C1373', '1', '2', 'C1374', 'O1340', '0', '2.654', '0.976', '3.656', '0.000', '0.174']
# ['O1340', '3', '2', 'C1373', 'H1339', '0', '0.976', '0.890', '1.870', '2.000', '-0.223']
# ['O1326', '3', '2', 'H1325', 'C1402', '0', '0.893', '0.943', '1.850', '2.000', '-0.223']
# ['C1402', '1', '3', 'O1326', 'H1404', 'C1401', '0', '0.943', '0.978', '1.625', '3.574', '0.000', '0.134']
# ['O1344', '3', '2', 'H1359', 'C94', '0', '0.875', '0.835', '1.714', '2.000', '-0.221']
# ['C1094', '1', '3', 'C1093', 'O1322', 'H1096', '0', '1.674', '1.005', '0.980', '3.682', '0.000', '0.116']
# ['O1322', '3', '2', 'C1094', 'H1321', '0', '1.005', '0.920', '1.944', '2.000', '-0.224']
# ['C94', '1', '3', 'O1344', 'C99', 'C95', '0', '0.835', '1.430', '1.380', '3.644', '0.000', '0.149']
# ['O1348', '3', '2', 'C1381', 'H1347', '0', '0.980', '0.812', '1.792', '2.000', '-0.221']
# ['C1381', '1', '2', 'O1348', 'C1382', '0', '0.980', '1.762', '2.765', '0.028', '0.181']
# ['C1050', '1', '2', 'H1061', 'O1338', '0', '0.939', '1.544', '2.483', '0.241', '0.123']
# 24
